# %% [markdown]
# <a href="https://colab.research.google.com/github/hira-dev834/Python-Journey/blob/main/Print_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, my name is Hira Akram")
print('my name is Hira Aktram')
print("""My name is Hira Akram
I am graduated in Software Engineering
I love coding""")
print("I am Hira Akram\nI love to write code\nalso I love to handle errors")
print("Python:\t\t\tHigh-level programming language")
print("C:\\Users\\Hira")
print("it\'s raining outside")
print("she said \"Good Morning\"")
print("HIRA AKRAM\b\b\b\b")
print(r"C:\Users\Hira")
# Out:
# Hello, my name is Hira Akram
# my name is Hira Aktram
# My name is Hira Akram
# I am graduated in Software Engineering
# I love coding
# I am Hira Akram
# I love to write code
# also I love to handle errors
# Python:			High-level programming language
# C:\Users\Hira
# it's raining outside
# she said "Good Morning"
# HIRA AKRAM
# C:\Users\Hira
