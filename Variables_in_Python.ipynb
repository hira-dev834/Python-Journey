# %% [markdown]
# <a href="https://colab.research.google.com/github/hira-dev834/Python-Journey/blob/main/Variables_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Hira"
language = "Python"
print("My name is", name)
print(name, "is learning" , language )
print(name, "want to become", language, "expert")
# Out:
# My name is Hira
# Hira is learning Python
# Hira want to become Python expert
